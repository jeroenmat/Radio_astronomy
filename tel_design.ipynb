# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
file = '/Users/jeroenmatthijssen/Downloads/MSc Astronomy/Courses/Radio Astronomy/telescope_design/test_data'

data = np.fromfile(file)

# %%
real = data[1::2]
compl = data[2::2]

plt.plot(real, color='red')
plt.plot(compl, color='blue')

# %%
fft_file = '/Users/jeroenmatthijssen/Downloads/MSc Astronomy/Courses/Radio Astronomy/telescope_design/FFT_data'
fft_data = np.fromfile(fft_file)

fft_real = fft_data[::2]
fft_compl = fft_data[1::2]

plt.figure(figsize=(9,6))
plt.plot(fft_real, color='red')
plt.plot(fft_compl, color='blue')
plt.show()

# %%
file_auto = '/Users/jeroenmatthijssen/Downloads/MSc Astronomy/Courses/Radio Astronomy/telescope_design/data_fft_autocorr_int'

data_auto = np.fromfile(file_auto, dtype=np.float32) # read out as float32 otherwise numbers blow up

# %%
plt.plot(data_auto, linewidth=0.5)
plt.xlim(5000, 10000)
# Out:
# (5000.0, 10000.0)
